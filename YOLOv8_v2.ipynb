# %% [markdown]
# <a href="https://colab.research.google.com/github/WafaSanaa/Computer_Vision/blob/main/YOLOv8_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Before Running the Script Please Make Sure you Select the Run Time as GPU

# %% [markdown]
# #**Mount the Google Drive with the Colab Notebook**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Set your Current Directory**

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# #**Created a Folder by the name Mining PPE Dataset**

# %%
# !mkdir MiningPPEProjectAS

# %% [markdown]
# #**Setting the Current Directory**

# %%
# %cd /content/drive/MyDrive/MiningPPEProjectAS
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS

# %% [markdown]
# #**Import the Required Libraries**

# %%
from IPython.display import Image

# %% [markdown]
# #**Clone the Github Repo**

# %%
# !git clone https://github.com/MuhammadMoin97/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 3878, done.
# remote: Total 3878 (delta 0), reused 0 (delta 0), pack-reused 3878 (from 1)
# Receiving objects: 100% (3878/3878), 1.82 MiB | 12.36 MiB/s, done.
# Resolving deltas: 100% (2693/2693), done.

# %%
# !pwd
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS

# %% [markdown]
# ##Setting the Current Directory

# %%
# %cd /content/drive/MyDrive/MiningPPEProjectAS/ultralytics
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics

# %% [markdown]
# ##Install all the Dependencies

# %%
# !pip install -e '.[dev]'
# Out:
# Obtaining file:///content/drive/MyDrive/MiningPPEProjectAS/ultralytics
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 102.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##Moving to the Required Directory

# %%
# %cd /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect

# %% [markdown]
# ##Importing the Dataset from the RoboFlow

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 110.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="CEUNDB2nxl8Ftgo3Cscc")
project = rf.workspace("mine-wgla3").project("plants-hpkup")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to plants-3 in yolov8:: 100%|██████████| 1382/1382 [00:09<00:00, 149.72it/s]

# %% [markdown]
# #**Training the Custom Model**

# %%
HOME = '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect'

# %%
# %cd {HOME}
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect

# %%
# %cd {dataset.location}
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3

# %%
###########ce code ne marche pas ##############
#%cd {HOME}

#!python train.py model=yolov8l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
#chaque image a un fichier .yaml qui contient son annotation
#epochs=100= nbre d'iteration

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.3
#     Uninstalling ultralytics-8.0.3:
#       Successfully uninstalled ultralytics-8.0.3
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8l.pt")  # Ce modèle sera téléchargé automatiquement s’il n’est pas local
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 232MB/s]

# %%
from ultralytics import YOLO
import torch  # ✅ Ajout de l'import manquant

model = YOLO("yolov8n.pt")  # modèle plus léger
data = "/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/data.yaml"
model.train(data=data, epochs=1, imgsz=416, workers=0, device="cuda" if torch.cuda.is_available() else "cpu")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 131MB/s]
# Ultralytics 8.3.145 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
#model.train(data="/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/parasites-2/data.yaml",            epochs=100,        imgsz=640,           workers=0)

# %% [markdown]
# #**Checking the Files inside the Train Folder**

# %%
# !ls /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/train
# Out:
# images	labels	labels.cache

# %% [markdown]
# #**Printing the Confusion Matrix**

# %%
#Image(filename = '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/train/confusion_matrix.png')
Image(filename = '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/runs/detect/train/confusion_matrix.png')

# %% [markdown]
# #**Printing the Training and the Validation Loss**

# %%
Image(filename = r'/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/runs/detect/train/results.png', width = 600)

# %% [markdown]
# #**Printing the Model Prediction on Validation Batch**

# %%
Image(filename = r'/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/runs/detect/train/val_batch2_pred.jpg', width =600)

# %% [markdown]
# #**Downloading the Weights From the Google Drive**

# %%
# %cd {HOME}
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect

# %%
# !gdown "https://drive.google.com/uc?id=1jG9vh3uYWbuLSiqgl1UozzlxY6jZbKh9&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jG9vh3uYWbuLSiqgl1UozzlxY6jZbKh9&confirm=t
# To: /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/best.pt
# 100% 52.0M/52.0M [00:01<00:00, 42.3MB/s]

# %% [markdown]
# #**Validate Custom Model**

# %%
# !pwd
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect

# %%
# !pip install ultralytics --upgrade

# %%
# Change directory to the root of the cloned ultralytics repository
# %cd /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect

# Now import the necessary modules
from ultralytics import YOLO
# The build_dataloader is not a public API and might not be needed for validation or prediction
# If you need to validate, the `model.val()` method is recommended.
# from ultralytics.yolo.data import build_dataloader # This line caused the error
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect

# %%
from ultralytics import YOLO

# Charger le modèle
model = YOLO("/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/runs/detect/train/weights/best.pt")

# Valider le modèle sur le dataset
results = model.val(data="/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/data.yaml")

# Afficher les résultats de validation
print("mAP50:", results.box.map50)
print("mAP50-95:", results.box.map)
# Out:
# Ultralytics 8.3.145 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 32.8±7.3 MB/s, size: 63.0 KB)
# val: Scanning /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/valid/labels.cache... 85 images, 0 backgrounds, 0 corrupt: 100%|██████████| 85/85 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:02<00:00,  2.68it/s]
#                    all         85        153    0.00486       0.81     0.0258     0.0106
# Speed: 3.5ms preprocess, 5.4ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to runs/detect/val
# mAP50: 0.025834889942071084
# mAP50-95: 0.010570582979118576

# %% [markdown]
# #**Inference with Custom Model**

# %% [markdown]
# #**Testing on Images**

# %%
from ultralytics import YOLO
from IPython.display import Image, display
import os

# Charger le modèle
model = YOLO("/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/runs/detect/train/weights/best.pt")

# Faire l'inférence
results = model.predict(source="/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/test/images/009_d90b1349_jpg.rf.c2d97bba381a20a73dc6a0b8a4adfc43.jpg", conf=0.1, save=True)

# Afficher l'image annotée dans Colab
output_dir = "runs/detect/predict"
image_name = os.listdir(output_dir)[0]
display(Image(filename=os.path.join(output_dir, image_name)))
# Out:
# image 1/1 /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/plants-3/test/images/009_d90b1349_jpg.rf.c2d97bba381a20a73dc6a0b8a4adfc43.jpg: 416x416 (no detections), 10.8ms
# Speed: 7.9ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict2

# %% [markdown]
# #**Display Output Images**

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/train2/*.jpg')[23:30]:
      display(Image(filename=image_path, width=600))
      print("\n")
